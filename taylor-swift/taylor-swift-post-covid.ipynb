# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the page to scrape
url = "https://www.the-numbers.com/movies/report/All/All/All/All/All/All/All/All/All/None/None/2021/None/None/None/None/None/None/None?show-release-date=On&show-domestic-box-office=On&show-international-box-office=On&show-worldwide-box-office=On&view-order-by=domestic-box-office&view-order-direction=desc"


# Define a custom user agent
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"

# Create headers with the custom user agent
headers = {
    "User-Agent": user_agent
}

# Send a GET request to the URL with custom headers
response = requests.get(url, headers=headers)

# %%
# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table containing the movie list
table = soup.find('table')

# Initialize empty lists to store movie data
movie_data = []

# Loop through each row in the table (skip the header row)
for row in table.find_all('tr')[1:]:
    columns = row.find_all('td')
    if len(columns) == 6:  # Ensure that the row has all the expected columns
        rank = columns[0].get_text(strip=True)
        release_date = columns[1].get_text(strip=True)
        title = columns[2].find('a').get_text(strip=True)
        url = columns[2].find('a').get('href')
        domestic_box_office = columns[3].get_text(strip=True)
        international_box_office = columns[4].get_text(strip=True)
        worldwide_box_office = columns[5].get_text(strip=True)
        movie_data.append([rank, release_date, title, url, domestic_box_office, international_box_office, worldwide_box_office])

# Create a DataFrame from the movie data
df = pd.DataFrame(movie_data, columns=["Rank", "Release Date", "Title", "URL", "Domestic Box Office", "International Box Office", "Worldwide Box Office"])

# Save the DataFrame to a CSV file
df.to_csv("movie_list.csv", index=False)

# %%
df.head()
# Out:
#   Rank  Release Date                        Title  \
# 0    1  Dec 17, 2021      Spider-Man: No Way Home
# 1    2  May 27, 2022            Top Gun: Maverick
# 2    3  Dec 16, 2022     Avatar: The Way of Water
# 3    4  Jul 21, 2023                       Barbie
# 4    5   Apr 5, 2023  The Super Mario Bros. Movie
#
#                                                  URL Domestic Box Office  \
# 0   /movie/Spider-Man-No-Way-Home-(2021)#tab=summary        $814,115,070
# 1         /movie/Top-Gun-Maverick-(2022)#tab=summary        $718,732,821
# 2  /movie/Avatar-The-Way-of-Water-(2022)#tab=summary        $684,075,767
# 3                   /movie/Barbie-(2023)#tab=summary        $634,806,975
# 4  /movie/Super-Mario-Bros-Movie-The-(2022)#tab=s...        $574,934,330
#
#   International Box Office Worldwide Box Office
# 0           $1,095,933,175       $1,910,048,245
# 1             $755,248,808       $1,473,981,629
# 2           $1,635,515,953       $2,319,591,720
# 3             $803,200,000       $1,438,006,975
# 4             $787,803,789       $1,362,738,119

# %%
for row in df:
    print(row)
# Out:
# Rank
# Release Date
# Title
# URL
# Domestic Box Office
# International Box Office
# Worldwide Box Office

# %%
def scrape_movie(url):
    movie_response = requests.get(f'https://www.the-numbers.com{url}', headers=headers)

    # Parse the HTML content of the page
    soup = BeautifulSoup(movie_response.text, 'html.parser')

    # Find the table with the specified selector
    tables = soup.select('#box_office_chart > table')
    table = tables[1]

    # Initialize empty lists to store table data
    table_data = []

    # Loop through each row in the table
    for row in table.find_all('tr'):
        columns = row.find_all('td')
        row_data = [col.get_text(strip=True) for col in columns]

        if len(row_data) > 0 and row_data[1] != "P":
            table_data.append(row_data)

    # Create a DataFrame from the table data
    df = pd.DataFrame(table_data, columns=['Date', 'Rank', 'Gross',	'%YD', '%LW', 'Theaters', 'Per Theater', 'Total Gross', 'Days'])

    return df

# %%
data = {}

for index, row in df.iterrows():
    print(index, row['Title'], row['URL'])
    data[row['Title']] = scrape_movie(row['URL'])
# Out:
# 0 Spider-Man: No Way Home /movie/Spider-Man-No-Way-Home-(2021)#tab=summary
# 1 Top Gun: Maverick /movie/Top-Gun-Maverick-(2022)#tab=summary
# 2 Avatar: The Way of Water /movie/Avatar-The-Way-of-Water-(2022)#tab=summary
# 3 Barbie /movie/Barbie-(2023)#tab=summary
# 4 The Super Mario Bros. Movie /movie/Super-Mario-Bros-Movie-The-(2022)#tab=summary
# 5 Black Panther: Wakanda Forever /movie/Black-Panther-Wakanda-Forever-(2022)#tab=summary
# 6 Doctor Strange in the Multiverse of M… /movie/Doctor-Strange-in-the-Multiverse-of-Madness-(2022)#tab=summary
# 7 Spider-Man: Across the Spider-Verse /movie/Spider-Man-Across-the-Spider-Verse-(2023)#tab=summary
# 8 Jurassic World: Dominion /movie/Jurassic-World-Dominion-(2022)#tab=summary
# 9 Minions: The Rise of Gru /movie/Minions-The-Rise-of-Gru-(2021)#tab=summary
# 10 The Batman /movie/Batman-The-(2021)#tab=summary
# 11 Guardians of the Galaxy Vol 3 /movie/Guardians-of-the-Galaxy-Vol-3-(2023)#tab=summary
# 12 Thor: Love and Thunder /movie/Thor-Love-and-Thunder-(2022)#tab=summary
# 13 Oppenheimer /movie/Oppenheimer-(2023)#tab=summary
# 14 The Little Mermaid /movie/Little-Mermaid-The-(2023)#tab=summary
# 15 Shang-Chi and the Legend of the Ten R… /movie/Shang-Chi-and-the-Legend-of-the-Ten-Rings-(2021)#tab=summary
# 16 Ant-Man and the Wasp: Quantumania /movie/Ant-Man-and-the-Wasp-Quantumania-(2023)#tab=summary
# 17 Venom: Let There be Carnage /movie/Venom-Let-There-be-Carnage#tab=summary
# 18 Sonic the Hedgehog 2 /movie/Sonic-the-Hedgehog-2-(2022)#tab=summary
# 19 John Wick: Chapter 4 /movie/John-Wick-Chapter-4-(2023)#tab=summary
# 20 Puss in Boots: The Last Wish /movie/Puss-in-Boots-The-Last-Wish-(2022)#tab=summary
# 21 Sound of Freedom /movie/Sound-of-Freedom-(2023)#tab=summary
# 22 Black Widow /movie/Black-Widow-(2021)#tab=summary
# 23 Indiana Jones and the Dial of Destiny /movie/Indiana-Jones-and-the-Dial-of-Destiny-(2023)#tab=summary
# 24 F9: The Fast Saga /movie/F9-The-Fast-Saga-(2021)#tab=summary
# 25 Mission: Impossible Dead Reckoning Pa… /movie/Mission-Impossible-Dead-Reckoning-Part-One-(2023)#tab=summary
# 26 Black Adam /movie/Black-Adam-(2022)#tab=summary
# 27 Eternals /movie/Eternals-(2021)#tab=summary
# 28 Sing 2 /movie/Sing-2-(2021)#tab=summary
# 29 No Time to Die /movie/No-Time-to-Die-(2021)#tab=summary
# 30 A Quiet Place: Part II /movie/Quiet-Place-Part-II-A-(2020)#tab=summary
# 31 Transformers: Rise of the Beasts /movie/Transformers-Rise-of-the-Beasts-(2023)#tab=summary
# 32 Creed III /movie/Creed-III-(2023)#tab=summary
# 33 Elemental /movie/Elemental-(2023)#tab=summary
# 34 Elvis /movie/Elvis-(2021)#tab=summary
# 35 Uncharted /movie/Uncharted-(2022)#tab=summary
# 36 Fast X /movie/Fast-X-(2023)#tab=summary
# 37 Ghostbusters: Afterlife /movie/Ghostbusters-Afterlife#tab=summary
# 38 Nope /movie/Nope-(2022)#tab=summary
# 39 Free Guy /movie/Free-Guy-(2020)#tab=summary
# 40 Lightyear /movie/Lightyear-(2022)#tab=summary
# 41 Teenage Mutant Ninja Turtles: Mutant … /movie/Teenage-Mutant-Ninja-Turtles-Mutant-Mayhem-(2023)#tab=summary
# 42 Jungle Cruise /movie/Jungle-Cruise-(2021)#tab=summary
# 43 Dune /movie/Dune-(2020)#tab=summary
# 44 Scream VI /movie/Scream-VI-(2023)#tab=summary
# 45 The Flash /movie/Flash-The#tab=summary
# 46 Smile /movie/Smile-(2022)#tab=summary
# 47 The Lost City /movie/Lost-City-The-(2022)#tab=summary
# 48 Bullet Train /movie/Bullet-Train-(2022)#tab=summary
# 49 Godzilla vs. Kong /movie/Godzilla-vs-Kong-(2020)#tab=summary
# 50 The Bad Guys /movie/Bad-Guys-The#tab=summary
# 51 Encanto /movie/Encanto-(2021)#tab=summary
# 52 Fantastic Beasts: The Secrets of Dumb… /movie/Fantastic-Beasts-The-Secrets-of-Dumbledore-(2021)#tab=summary
# 53 M3GAN /movie/M3GAN#tab=summary
# 54 DC League of Super Pets /movie/DC-League-of-Super-Pets-(2022)#tab=summary
# 55 Dungeons & Dragons: Honor Among Thieves /movie/Dungeons-and-Dragons-Honor-Among-Thieves-(2023)#tab=summary
# 56 Halloween Kills /movie/Halloween-Kills-(2021)#tab=summary
# 57 Where the Crawdads Sing /movie/Where-the-Crawdads-Sing#tab=summary
# 58 The Black Phone /movie/Black-Phone-The-(2022)#tab=summary
# 59 The Equalizer 3 /movie/Equalizer-3-The-(2023)#tab=summary
# 60 Cruella /movie/Cruella-(2021)#tab=summary
# 61 The Nun II /movie/Nun-II-The-(2023)#tab=summary
# 62 Meg 2: The Trench /movie/Meg-2-The-Trench-(2023)#tab=summary
# 63 Insidious: The Red Door /movie/Insidious-The-Red-Door-(2023)#tab=summary
# 64 Scream /movie/Scream-(2022)#tab=summary
# 65 Everything Everywhere All At Once /movie/Everything-Everywhere-All-At-Once-(2022)#tab=summary
# 66 Morbius /movie/Morbius-(2020)#tab=summary
# 67 Blue Beetle /movie/Blue-Beetle#tab=summary
# 68 Space Jam: A New Legacy /movie/Space-Jam-A-New-Legacy#tab=summary
# 69 Ticket to Paradise /movie/Ticket-to-Paradise-(2022)#tab=summary
# 70 Haunted Mansion /movie/Haunted-Mansion-(2023)#tab=summary
# 71 The Woman King /movie/Woman-King-The-(2022)#tab=summary
# 72 Evil Dead Rise /movie/Evil-Dead-Rise-(2023)#tab=summary
# 73 The Conjuring: The Devil Made Me Do It /movie/Conjuring-The-Devil-Made-Me-Do-It-The#tab=summary
# 74 Cocaine Bear /movie/Cocaine-Bear-(2023)#tab=summary
# 75 A Man Called Otto /movie/Man-Called-Otto-A-(2022)#tab=summary
# 76 Halloween Ends /movie/Halloween-Ends-(2022)#tab=summary
# 77 Dog /movie/Dog-(2021-Dir-Channing-Tatum)#tab=summary
# 78 Candyman /movie/Candyman-(2020)#tab=summary
# 79 jackass forever /movie/Jackass-Forever-(2021)#tab=summary
# 80 Shazam! Fury of the Gods /movie/Shazam-Fury-of-the-Gods-(2022)#tab=summary
# 81 The Boss Baby: Family Business /movie/Boss-Baby-Family-Business-The-(2021)#tab=summary
# 82 The Addams Family 2 /movie/Addams-Family-2-The#tab=summary
# 83 The Suicide Squad /movie/Suicide-Squad-The-(2021)#tab=summary
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/gambit/lib/python3.11/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gambit/lib/python3.11/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 9 columns passed, passed data had 8 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> for index, row in df.iterrows():
#       <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     print(index, row['Title'], row['URL'])
# ----> <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     data[row['Title']] = scrape_movie(row['URL'])
#
# /Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb Cell 6 line 2
#      <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a>         table_data.append(row_data)
#      <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a> # Create a DataFrame from the table data
# ---> <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> df = pd.DataFrame(table_data, columns=['Date', 'Rank', 'Gross',	'%YD', '%LW', 'Theaters', 'Per Theater', 'Total Gross', 'Days'])
#      <a href='vscode-notebook-cell:/Users/adam/Desktop/quant-research/taylor-swift-post-covid.ipynb#W5sZmlsZQ%3D%3D?line=24'>25</a> return df
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gambit/lib/python3.11/site-packages/pandas/core/frame.py:809, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     807     if columns is not None:
#     808         columns = ensure_index(columns)
# --> 809     arrays, columns, index = nested_data_to_arrays(
#     810         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     811         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     812         data,
#     813         columns,
#     814         index,  # type: ignore[arg-type]
#     815         dtype,
#     816     )
#     817     mgr = arrays_to_mgr(
#     818         arrays,
#     819         columns,
#    (...)
#     822         typ=manager,
#     823     )
#     824 else:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gambit/lib/python3.11/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gambit/lib/python3.11/site-packages/pandas/core/internals/construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/gambit/lib/python3.11/site-packages/pandas/core/internals/construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 9 columns passed, passed data had 8 columns

# %%
clean_data = []

def dval(s):
    return float(s.replace("$", "").replace(",", ""))

for movie_name in data:
    d1 = data[movie_name].iloc[0]['Gross']
    d2 = data[movie_name].iloc[1]['Gross']
    d3 = data[movie_name].iloc[2]['Gross']
    clean_data.append([movie_name, dval(d1), dval(d2), dval(d3)])

# %%
import matplotlib.pyplot as plt
# Compute ratios
ratios = [(sum(movie[1:]) / (movie[1])) for movie in clean_data]

# Plot histogram
plt.hist(ratios, bins=15, edgecolor='black')
plt.xlabel('Ratio')
plt.ylabel('Number of Movies')
plt.title('Histogram of Ratios')
plt.show()

# %%
# Compute ratios
ratios = [(sum(movie[1:]) / movie[1]) for movie in clean_data]

# Count the occurrences where the ratio exceeds 2.5
count_exceeding_2_5 = sum(1 for ratio in ratios if ratio > 2.5)

# Calculate the probability
probability = count_exceeding_2_5 / len(ratios)

print(f"The probability that the ratio exceeds 2.5 is {probability:.2%}")
# Out:
# The probability that the ratio exceeds 2.5 is 38.55%

# %%
ratios = [(sum(movie[1:]) / (movie[1] + movie[2])) for movie in clean_data]

# Plot histogram
plt.hist(ratios, bins=15, edgecolor='black')
plt.xlabel('Ratio')
plt.ylabel('Number of Movies')
plt.title('Histogram of Ratios')
plt.show()

# %%
DAY_1_EARNINGS = 40 # mm
DAY_2_EARNINGS = 40

ratio_bound = 100/(DAY_1_EARNINGS + DAY_2_EARNINGS)

# Compute ratios
ratios = [(sum(movie[1:]) / (movie[1] + movie[2])) for movie in clean_data]

# Count the occurrences where the ratio exceeds 2.5
count_exceeding_2_5 = sum(1 for ratio in ratios if ratio > ratio_bound)

# Calculate the probability
probability = count_exceeding_2_5 / len(ratios)

print(f"The probability that the ratio exceeds 2.5 is {probability:.2%}")
# Out:
# The probability that the ratio exceeds 2.5 is 92.77%

# %%
DAY_1_EARNINGS = 39  # mm

def calculate_probability(DAY_2_EARNINGS):
    ratio_bound = 100 / (DAY_1_EARNINGS + DAY_2_EARNINGS)
    ratios = [(sum(movie[1:]) / (movie[1] + movie[2])) for movie in clean_data]
    count_exceeding_bound = sum(1 for ratio in ratios if ratio > ratio_bound)
    return count_exceeding_bound / len(ratios)

# Get the probabilities for each value of DAY_2_EARNINGS from 0 to 50
probabilities = [calculate_probability(i) for i in range(51)]

# Plot
plt.plot(range(51), probabilities, marker='o', linestyle='-')
plt.xlabel('Day 2 Earnings')
plt.ylabel('Contract Fair')
plt.title('Contract Fair Given Day Earnings')
plt.grid(True)
plt.show()

# %%
DAY_1_EARNINGS = 39  # mm

def calculate_probability(DAY_2_EARNINGS):
    ratio_bound = 125 / (DAY_1_EARNINGS + DAY_2_EARNINGS)
    ratios = [(sum(movie[1:]) / (movie[1] + movie[2])) for movie in clean_data]
    count_exceeding_bound = sum(1 for ratio in ratios if ratio > ratio_bound)
    return count_exceeding_bound / len(ratios)

# Get the probabilities for each value of DAY_2_EARNINGS from 0 to 50
probabilities = [calculate_probability(i) for i in range(51)]

# Plot
plt.plot(range(51), probabilities, marker='o', linestyle='-')
plt.xlabel('Day 2 Earnings')
plt.ylabel('Contract Fair')
plt.title('125 Strike Contract Fair Given Day Earnings')
plt.grid(True)
plt.show()

# %%
DAY_1_EARNINGS = 39

ratio_bound = 100/(DAY_1_EARNINGS)

# Compute ratios
ratios = [(sum(movie[1:]) / (movie[1])) for movie in clean_data]

# Count the occurrences where the ratio exceeds 2.5
count_exceeding_2_5 = sum(1 for ratio in ratios if ratio > ratio_bound)

# Calculate the probability
probability = count_exceeding_2_5 / len(ratios)

print(f"The win probability {probability:.2%}")
# Out:
# The win probability 28.92%

# %%
import matplotlib.pyplot as plt
# Compute ratios
ratios = [movie[3] / movie[1] for movie in clean_data]

# Plot histogram
plt.hist(ratios, bins=15, edgecolor='black')
plt.xlabel('Ratio')
plt.ylabel('Number')
plt.title('Day 3 Earnings / Day 1 Earnings')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Assuming clean_data is already defined
ratios = [movie[3] / movie[2] for movie in clean_data]

# Estimate the parameters of the normal distribution
# mu, std = norm.fit(ratios)
mu = 0.8
std = 0.15

# Plot histogram
plt.hist(ratios, bins=25, edgecolor='black', density=True, alpha=0.6, label="Data")

# Plot the normal distribution curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label="Fit")

# Set title and labels
plt.title(f"Fit results: mu = {mu:.2f},  std = {std:.2f}")
plt.xlabel('Ratio')
plt.ylabel('Density')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming clean_data is already defined
day2_earnings = [movie[2] for movie in clean_data]
day3_earnings = [movie[3] for movie in clean_data]

# Linear regression
slope, intercept = np.polyfit(day2_earnings, day3_earnings, 1)

# Scatter plot
plt.scatter(day2_earnings, day3_earnings, label='Data', color='blue', alpha=0.6)

# Plot regression line
x = np.array(day2_earnings)
y = slope * x + intercept
plt.plot(x, y, color='red', label=f'y={slope:.2f}x + {intercept:.2f}')

# Set title and labels
plt.title('Linear Regression: Day 3 Earnings vs Day 1 Earnings')
plt.xlabel('Day 1 Earnings')
plt.ylabel('Day 3 Earnings')
plt.legend()
plt.grid(True)

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Assuming clean_data is already defined
day1_earnings = [movie[1] for movie in clean_data]
day2_earnings = [movie[2] for movie in clean_data]
day3_earnings = [movie[3] for movie in clean_data]

# Reshape the data and prepare the feature matrix X and target vector y
X = list(zip(day1_earnings, day2_earnings))
y = day3_earnings

# Create and fit the model
model = LinearRegression().fit(X, y)

# Print coefficients
print(f"a1 (coefficient for Day 1 Earnings): {model.coef_[0]:.2f}")
print(f"a2 (coefficient for Day 2 Earnings): {model.coef_[1]:.2f}")
print(f"Intercept: {model.intercept_:.2f}")
# Out:
# a1 (coefficient for Day 1 Earnings): 0.02
# a2 (coefficient for Day 2 Earnings): 0.79
# Intercept: 7138.73

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def get_target(day_2_earnings):
    # target ratio day 3 / day 2 to hit 100mm
    target = (125e6 - 39e6 - day_2_earnings) / day_2_earnings
    return target

def prob_hitting_target(target):
    mu = 0.8
    sigma = 0.15
    return 1 - norm.cdf(target, mu, sigma)

x_vals = np.linspace(10000000, 60000000, 50)
y_vals = [prob_hitting_target(get_target(x)) for x in x_vals]

plt.figure(figsize=(10,6))
plt.plot(x_vals, y_vals, '-o', label='Probability of hitting target')
plt.xlabel('Day 2 Earnings ($)')
plt.ylabel('Probability')
plt.title('Probability of Hitting Target vs. Day 2 Earnings')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Compute ratios
ratios = [(sum(movie[1:]) / (movie[1] + movie[2])) for movie in clean_data]

# Count the occurrences where the ratio exceeds 2.5
count_exceeding_2_5 = sum(1 for ratio in ratios if ratio > 1.39)

# Calculate the probability
probability = count_exceeding_2_5 / len(ratios)

print(f"The probability that the ratio exceeds 2.5 is {probability:.2%}")


for movie in clean_data:
    if (sum(movie[1:]) / (movie[1] + movie[2])) > 1.39:
        print(movie[0])
# Out:
# The probability that the ratio exceeds 2.5 is 19.28%
# Top Gun: Maverick
# The Super Mario Bros. Movie
# Oppenheimer
# The Little Mermaid
# Shang-Chi and the Legend of the Ten R…
# Puss in Boots: The Last Wish
# Indiana Jones and the Dial of Destiny
# Mission: Impossible Dead Reckoning Pa…
# Uncharted
# Teenage Mutant Ninja Turtles: Mutant …
# Godzilla vs. Kong
# Encanto
# The Equalizer 3
# Cruella
# A Man Called Otto
# Dog
